# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

from sklearn.preprocessing import MinMaxScaler

# %%
# mysql username, password, and database name
MYSQL_ADDRESS = '127.0.0.1'

MYSQL_PORT = '3306'
MYSQL_USERNAME = 'vegas'
MYSQL_PASSWORD = 'VrichCrich99'
MYSQL_DBNAME = 'univers'


mysql_str = ('mysql://{username}:{password}@{ipaddress}:{port}/{dbname}'.format(username=MYSQL_USERNAME, password=MYSQL_PASSWORD, ipaddress=MYSQL_ADDRESS, port=MYSQL_PORT, dbname=MYSQL_DBNAME))
engine = create_engine(mysql_str)

# %%
appstech_labs_id = 1
df = pd.read_sql_query(f"SELECT * FROM user_sales_table where business_id='{appstech_labs_id}'", engine, index_col='txn_date', parse_dates=['txn_date'])
df.head()
# Out:
#             Id  business_id      source         customer_name customer_id  \
# txn_date
# 2020-08-31   9            1  quickbooks  Amy's Bird Sanctuary           1
# 2020-05-19  10            1  quickbooks  Bill's Windsurf Shop           2
# 2020-08-29  11            1  quickbooks       Dylan Sollfrank           6
# 2020-08-22  12            1  quickbooks             Cool Cars           3
# 2020-08-25  13            1  quickbooks          55 Twin Lane           9
#
#            sales_type  gross_amount  gross_cost   margin  discount_amount  \
# txn_date
# 2020-08-31    INVOICE        100.00         0.0   100.00              0.0
# 2020-05-19    INVOICE        175.00         0.0   175.00              0.0
# 2020-08-29       SALE        338.00         0.0   338.00              0.0
# 2020-08-22    INVOICE       2194.48        28.0  2166.48              0.0
# 2020-08-25    INVOICE         50.00         0.0    50.00              0.0
#
#             ...  business_currency business_currency_symbol txn_currency  \
# txn_date    ...
# 2020-08-31  ...                USD                        $          USD
# 2020-05-19  ...                USD                        $          USD
# 2020-08-29  ...                USD                        $          USD
# 2020-08-22  ...                USD                        $          USD
# 2020-08-25  ...                USD                        $          USD
#
#            txn_currency_symbol   due_date exchange_rate  active  \
# txn_date
# 2020-08-31                   $ 2020-09-30           1.0       1
# 2020-05-19                   $ 2020-06-18           1.0       1
# 2020-08-29                   $        NaT           1.0       1
# 2020-08-22                   $ 2020-09-21           1.0       1
# 2020-08-25                   $ 2020-09-24           1.0       1
#
#                     created_on          updated_on deleted_on
# txn_date
# 2020-08-31 2020-11-13 14:17:04 2020-11-13 14:17:15       None
# 2020-05-19 2020-11-13 14:17:04 2020-11-13 14:17:15       None
# 2020-08-29 2020-11-13 14:17:04 2020-11-13 14:17:15       None
# 2020-08-22 2020-11-13 14:17:04 2020-11-13 14:17:15       None
# 2020-08-25 2020-11-13 14:17:04 2020-11-13 14:17:15       None
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (35, 21)

# %%
threshold = 0.7
df.isna().sum()
# Out:
# Id                           0
# business_id                  0
# source                       0
# customer_name                0
# customer_id                  0
# sales_type                   0
# gross_amount                 0
# gross_cost                   0
# margin                       0
# discount_amount              0
# tax_amount                   0
# business_currency            0
# business_currency_symbol     0
# txn_currency                 0
# txn_currency_symbol          0
# due_date                     4
# exchange_rate                0
# active                       0
# created_on                   0
# updated_on                   0
# deleted_on                  35
# dtype: int64

# %%
df = df[df.columns[df.isna().mean() < threshold]]
df = df.loc[df.isna().mean(axis=1) < threshold]

df.tail()
# Out:
#              Id  business_id      source              customer_name  \
# txn_date
# 2020-09-02  103            1  quickbooks           Geeta Kalapatapu
# 2020-09-02  106            1  quickbooks   Rondonuwu Fruit and Vegi
# 2020-09-03  119            1  quickbooks                   Mark Cho
# 2020-09-03  129            1  quickbooks       0969 Ocean View Road
# 2020-09-03  130            1  quickbooks  Sonnenschein Family Store
#
#            customer_id sales_type  gross_amount  gross_cost  margin  \
# txn_date
# 2020-09-02          10    INVOICE        582.40       145.0  437.40
# 2020-09-02          21    INVOICE         75.40         0.0   75.40
# 2020-09-03          17    INVOICE        290.72       137.0  153.72
# 2020-09-03           8    INVOICE        478.00       135.0  343.00
# 2020-09-03          24    INVOICE        335.18       135.0  200.18
#
#             discount_amount  tax_amount business_currency  \
# txn_date
# 2020-09-02              0.0       46.60               USD
# 2020-09-02              0.0        3.60               USD
# 2020-09-03              0.0       23.28               USD
# 2020-09-03              0.0        0.00               USD
# 2020-09-03              0.0       26.82               USD
#
#            business_currency_symbol txn_currency txn_currency_symbol  \
# txn_date
# 2020-09-02                        $          USD                   $
# 2020-09-02                        $          USD                   $
# 2020-09-03                        $          USD                   $
# 2020-09-03                        $          USD                   $
# 2020-09-03                        $          USD                   $
#
#              due_date  exchange_rate  active          created_on  \
# txn_date
# 2020-09-02 2020-10-02            1.0       1 2020-11-13 14:17:04
# 2020-09-02 2020-10-02            1.0       1 2020-11-13 14:17:04
# 2020-09-03 2020-10-03            1.0       1 2020-11-13 14:17:04
# 2020-09-03 2020-10-03            1.0       1 2020-11-13 14:17:04
# 2020-09-03 2020-10-03            1.0       1 2020-11-13 14:17:04
#
#                     updated_on
# txn_date
# 2020-09-02 2020-11-13 14:17:15
# 2020-09-02 2020-11-13 14:17:15
# 2020-09-03 2020-11-13 14:17:15
# 2020-09-03 2020-11-13 14:17:15
# 2020-09-03 2020-11-13 14:17:15

# %%
upper_lim = df["gross_amount"].quantile(.95)
lower_lim = df["gross_amount"].quantile(.05)

print(f"upper limit {upper_lim} vs lower limit {lower_lim}")
df = df[(df["gross_amount"] < upper_lim) & (df["gross_amount"] > lower_lim)]
# Out:
# upper limit 811.4999999999994 vs lower limit 73.5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 31 entries, 2020-08-31 to 2020-09-03
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        31 non-null     int64
#  1   business_id               31 non-null     int64
#  2   source                    31 non-null     object
#  3   customer_name             31 non-null     object
#  4   customer_id               31 non-null     object
#  5   sales_type                31 non-null     object
#  6   gross_amount              31 non-null     float64
#  7   gross_cost                31 non-null     float64
#  8   margin                    31 non-null     float64
#  9   discount_amount           31 non-null     float64
#  10  tax_amount                31 non-null     float64
#  11  business_currency         31 non-null     object
#  12  business_currency_symbol  31 non-null     object
#  13  txn_currency              31 non-null     object
#  14  txn_currency_symbol       31 non-null     object
#  15  due_date                  27 non-null     datetime64[ns]
#  16  exchange_rate             31 non-null     float64
#  17  active                    31 non-null     int64
#  18  created_on                31 non-null     datetime64[ns]
#  19  updated_on                31 non-null     datetime64[ns]
# dtypes: datetime64[ns](3), float64(6), int64(3), object(8)
# memory usage: 5.1+ KB

# %%
numeric_feats = df.dtypes[df.dtypes != "object"].index
numeric_feats = df[numeric_feats].dtypes[df.dtypes != "datetime64[ns]"].index
numeric_feats = df[numeric_feats].dtypes[df.dtypes != "int64"].index

imp_feats = []

cormat = df[numeric_feats].corr().fillna(0)

for feat in numeric_feats:
    try:
        if cormat[feat][0] > 0.2:
            imp_feats.append(feat)
    except:
        pass
        

df = df[imp_feats]
df
# Out:
#             gross_amount  gross_cost  margin  tax_amount
# txn_date
# 2020-08-31        100.00         0.0  100.00        8.00
# 2020-05-19        175.00         0.0  175.00        0.00
# 2020-08-29        338.00         0.0  338.00        0.00
# 2020-07-26         79.60         0.0   79.60        6.40
# 2020-08-09        750.00         0.0  750.00        0.00
# 2020-08-09        225.00         0.0  225.00        0.00
# 2020-08-31        104.00         0.0  104.00        0.00
# 2020-09-01        375.00         0.0  375.00        0.00
# 2020-09-01         79.00         0.0   79.00        0.00
# 2020-08-20        275.00       140.0  135.00        0.00
# 2020-08-22         75.00         0.0   75.00        6.00
# 2020-08-30        140.00         0.0  140.00        0.00
# 2020-07-16         75.00         0.0   75.00        0.00
# 2020-08-18         80.00         0.0   80.00        0.00
# 2020-08-25         80.00         0.0   80.00        0.00
# 2020-09-01         80.00         0.0   80.00        0.00
# 2020-08-12        425.00       125.0  300.00       34.00
# 2020-08-12         75.00         0.0   75.00        6.00
# 2020-06-26        156.00        81.0   75.00        0.00
# 2020-07-17        205.00         0.0  205.00        0.00
# 2020-07-17         85.00         0.0   85.00        0.00
# 2020-07-17         75.00         0.0   75.00        6.00
# 2020-07-17        421.60       125.0  296.60       38.40
# 2020-05-19        216.50         0.0  216.50       10.50
# 2020-06-19        365.00       125.0  240.00       22.00
# 2020-08-31        384.28         0.0  384.28       30.72
# 2020-09-02        582.40       145.0  437.40       46.60
# 2020-09-02         75.40         0.0   75.40        3.60
# 2020-09-03        290.72       137.0  153.72       23.28
# 2020-09-03        478.00       135.0  343.00        0.00
# 2020-09-03        335.18       135.0  200.18       26.82

# %%
df = df.resample("D").sum()
df = df.loc[df["gross_amount"] > 0]

# %%
df
# Out:
#             gross_amount  gross_cost  margin  tax_amount
# txn_date
# 2020-05-19        391.50         0.0  391.50       10.50
# 2020-06-19        365.00       125.0  240.00       22.00
# 2020-06-26        156.00        81.0   75.00        0.00
# 2020-07-16         75.00         0.0   75.00        0.00
# 2020-07-17        786.60       125.0  661.60       44.40
# 2020-07-26         79.60         0.0   79.60        6.40
# 2020-08-09        975.00         0.0  975.00        0.00
# 2020-08-12        500.00       125.0  375.00       40.00
# 2020-08-18         80.00         0.0   80.00        0.00
# 2020-08-20        275.00       140.0  135.00        0.00
# 2020-08-22         75.00         0.0   75.00        6.00
# 2020-08-25         80.00         0.0   80.00        0.00
# 2020-08-29        338.00         0.0  338.00        0.00
# 2020-08-30        140.00         0.0  140.00        0.00
# 2020-08-31        588.28         0.0  588.28       38.72
# 2020-09-01        534.00         0.0  534.00        0.00
# 2020-09-02        657.80       145.0  512.80       50.20
# 2020-09-03       1103.90       407.0  696.90       50.10

# %%
data = pd.DataFrame(df["gross_amount"])
data["log+1"] = (data["gross_amount"] + 1).transform(np.log)
data["log(x-min(x)+1)"] = (data["gross_amount"] - data["gross_amount"].min() + 1).transform(np.log)

data["inverse_log"] = (data["log(x-min(x)+1)"]).transform(np.exp) + data["gross_amount"].min() - 1
data

df["gross_amount"] = (df["gross_amount"] - df["gross_amount"].min() + 1).transform(np.log)

_scaler = MinMaxScaler()
df["gross_amount"] = _scaler.fit_transform(df["gross_amount"].values.reshape(-1, 1))
df.head()
# Out:
#             gross_amount  gross_cost  margin  tax_amount
# txn_date
# 2020-05-19      0.830373         0.0   391.5        10.5
# 2020-06-19      0.817810       125.0   240.0        22.0
# 2020-06-26      0.635229        81.0    75.0         0.0
# 2020-07-16      0.000000         0.0    75.0         0.0
# 2020-07-17      0.946910       125.0   661.6        44.4

# %%
# df.to_csv("../universe_dataset.csv")

# %%
dataset = df.values
dataset.shape
# Out:
# (18, 4)

# %%
def split_sequences(data, look_back:int=3):
    x, y = list(), list()
    
    for i in range(len(data)):
        end_start = i + look_back
        
        if end_start >= len(data):
            break
        
        x.append(data[i:end_start, -1])
        y.append(data[end_start-1, -1])
        
        end_start += 1
    
    return np.array(x), np.array(y)

X, y = split_sequences(dataset)
# X = X.reshape(-1, X.shape[1]*X.shape[2])
# X = X.reshape(-1, 1, X.shape[1])
y = y.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (15, 3) (15, 1)

# %%
X.ndim
# Out:
# 2

# %%
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from sklearn.model_selection import TimeSeriesSplit, train_test_split

from sklearn.metrics import r2_score

# %%
# tscv = TimeSeriesSplit(n_splits=2)

# for train_index, test_index in tscv.split(X):
#     print("TRAIN:", train_index, "TEST:", test_index)
#     X_train, X_test = X[train_index], X[test_index]
#     y_train, y_test = y[train_index], y[test_index]

X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False, test_size=0.25)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((11, 3), (11, 1), (4, 3), (4, 1))

# %%
X_train_test = np.concatenate((X_train, X_test))
y_train_test = np.concatenate((y_train, y_test))
X_train_test.shape, y_train.shape
# Out:
# ((15, 3), (11, 1))

# %%
# pd.DataFrame(data={"gross_amount-2": X_train[:, 0], "gross_amount-1": X_train[:, 1], "gross_amount": X_train[:, 2], "gross_amount+1": y_train[:, 0]})

# %%
# pd.DataFrame(data={"gross_amount-2": X_test[:, 0], "gross_amount-1": X_test[:, 1], "gross_amount": X_test[:, 2], "gross_amount+1": y_test[:, 0]})

# %%
def create_model():
    model = Sequential()

    model.add(Dense(50, input_shape=(X_train.shape[1],)))
    model.add(Dense(50))
    model.add(Dense(100))
    model.add(Dense(y_train.shape[1]))

    # model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
    # model.add(LSTM(50, activation="linear"))
    # model.add(Dense(100))
    # model.add(Dense(y_train.shape[1]))

    model.compile(loss="mape", optimizer="adam", metrics=["mape"])
    model.compile(optimizer="adam", loss="mse")
    
    return model

# %%
model = create_model()

cb_callback = tf.keras.callbacks.ModelCheckpoint("checkpoint/", monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)
model.fit(X_train, y_train, batch_size=5, epochs=80, verbose=1, shuffle=False, validation_data=(X_test, y_test), callbacks=[cb_callback])
# Out:
# Epoch 1/80
# 1/3 [=========>....................] - ETA: 0s - loss: 702.1081
# Epoch 00001: val_loss improved from inf to 272.50278, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 361ms/step - loss: 474.3852 - val_loss: 272.5028
# Epoch 2/80
# 1/3 [=========>....................] - ETA: 0s - loss: 248.5963
# Epoch 00002: val_loss improved from 272.50278 to 38.31711, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 334ms/step - loss: 160.8352 - val_loss: 38.3171
# Epoch 3/80
# 1/3 [=========>....................] - ETA: 0s - loss: 44.3749
# Epoch 00003: val_loss improved from 38.31711 to 5.00932, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 276ms/step - loss: 24.6774 - val_loss: 5.0093
# Epoch 4/80
# 3/3 [==============================] - ETA: 0s - loss: 5.1344
# Epoch 00004: val_loss did not improve from 5.00932
# 3/3 [==============================] - 0s 54ms/step - loss: 5.1344 - val_loss: 43.1189
# Epoch 5/80
# 1/3 [=========>....................] - ETA: 0s - loss: 43.9282
# Epoch 00005: val_loss did not improve from 5.00932
# 3/3 [==============================] - 0s 74ms/step - loss: 36.4770 - val_loss: 54.1551
# Epoch 6/80
# 1/3 [=========>....................] - ETA: 0s - loss: 62.3912
# Epoch 00006: val_loss did not improve from 5.00932
# 3/3 [==============================] - 0s 54ms/step - loss: 45.4437 - val_loss: 32.6724
# Epoch 7/80
# 3/3 [==============================] - ETA: 0s - loss: 26.0170
# Epoch 00007: val_loss did not improve from 5.00932
# 3/3 [==============================] - 0s 55ms/step - loss: 26.0170 - val_loss: 9.2933
# Epoch 8/80
# 1/3 [=========>....................] - ETA: 0s - loss: 10.7346
# Epoch 00008: val_loss improved from 5.00932 to 0.21159, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 294ms/step - loss: 6.4329 - val_loss: 0.2116
# Epoch 9/80
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2746
# Epoch 00009: val_loss did not improve from 0.21159
# 3/3 [==============================] - 0s 28ms/step - loss: 0.2573 - val_loss: 3.0099
# Epoch 10/80
# 1/3 [=========>....................] - ETA: 0s - loss: 3.7012
# Epoch 00010: val_loss did not improve from 0.21159
# 3/3 [==============================] - 0s 41ms/step - loss: 3.3819 - val_loss: 8.2819
# Epoch 11/80
# 1/3 [=========>....................] - ETA: 0s - loss: 9.1169
# Epoch 00011: val_loss did not improve from 0.21159
# 3/3 [==============================] - 0s 70ms/step - loss: 7.0717 - val_loss: 9.3275
# Epoch 12/80
# 1/3 [=========>....................] - ETA: 0s - loss: 9.5739
# Epoch 00012: val_loss did not improve from 0.21159
# 3/3 [==============================] - 0s 61ms/step - loss: 6.8857 - val_loss: 5.8240
# Epoch 13/80
# 3/3 [==============================] - ETA: 0s - loss: 3.7863
# Epoch 00013: val_loss did not improve from 0.21159
# 3/3 [==============================] - 0s 70ms/step - loss: 3.7863 - val_loss: 1.6139
# Epoch 14/80
# 1/3 [=========>....................] - ETA: 0s - loss: 1.5035
# Epoch 00014: val_loss improved from 0.21159 to 0.00920, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 288ms/step - loss: 0.8770 - val_loss: 0.0092
# Epoch 15/80
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0023
# Epoch 00015: val_loss did not improve from 0.00920
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0394 - val_loss: 0.7871
# Epoch 16/80
# 1/3 [=========>....................] - ETA: 0s - loss: 0.8091
# Epoch 00016: val_loss did not improve from 0.00920
# 3/3 [==============================] - 0s 27ms/step - loss: 0.7353 - val_loss: 1.5854
# Epoch 17/80
# 1/3 [=========>....................] - ETA: 0s - loss: 1.7246
# Epoch 00017: val_loss did not improve from 0.00920
# 3/3 [==============================] - 0s 53ms/step - loss: 1.3227 - val_loss: 1.2387
# Epoch 18/80
# 1/3 [=========>....................] - ETA: 0s - loss: 1.4804
# Epoch 00018: val_loss did not improve from 0.00920
# 3/3 [==============================] - 0s 51ms/step - loss: 1.0384 - val_loss: 0.4322
# Epoch 19/80
# 1/3 [=========>....................] - ETA: 0s - loss: 0.5924
# Epoch 00019: val_loss did not improve from 0.00920
# 3/3 [==============================] - 0s 55ms/step - loss: 0.3754 - val_loss: 0.0269
# Epoch 20/80
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0467
# Epoch 00020: val_loss did not improve from 0.00920
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0257 - val_loss: 0.1064
# Epoch 21/80
# 3/3 [==============================] - ETA: 0s - loss: 0.0928
# Epoch 00021: val_loss did not improve from 0.00920
# 3/3 [==============================] - 0s 59ms/step - loss: 0.0928 - val_loss: 0.3011
# Epoch 22/80
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3148
# Epoch 00022: val_loss did not improve from 0.00920
# 3/3 [==============================] - 0s 39ms/step - loss: 0.2454 - val_loss: 0.3237
# Epoch 23/80
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3304
# Epoch 00023: val_loss did not improve from 0.00920
# 3/3 [==============================] - 0s 29ms/step - loss: 0.2331 - val_loss: 0.1731
# Epoch 24/80
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1550
# Epoch 00024: val_loss did not improve from 0.00920
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0991 - val_loss: 0.0318
# Epoch 25/80
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0157
# Epoch 00025: val_loss did not improve from 0.00920
# 3/3 [==============================] - 0s 46ms/step - loss: 0.0095 - val_loss: 0.0146
# Epoch 26/80
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0175
# Epoch 00026: val_loss did not improve from 0.00920
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0213 - val_loss: 0.0548
# Epoch 27/80
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0713
# Epoch 00027: val_loss did not improve from 0.00920
# 3/3 [==============================] - 0s 37ms/step - loss: 0.0591 - val_loss: 0.0564
# Epoch 28/80
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0735
# Epoch 00028: val_loss did not improve from 0.00920
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0547 - val_loss: 0.0246
# Epoch 29/80
# 3/3 [==============================] - ETA: 0s - loss: 0.0218
# Epoch 00029: val_loss improved from 0.00920 to 0.00698, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 292ms/step - loss: 0.0218 - val_loss: 0.0070
# Epoch 30/80
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0021
# Epoch 00030: val_loss did not improve from 0.00698
# 3/3 [==============================] - 0s 49ms/step - loss: 0.0031 - val_loss: 0.0153
# Epoch 31/80
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0069
# Epoch 00031: val_loss did not improve from 0.00698
# 3/3 [==============================] - 0s 54ms/step - loss: 0.0077 - val_loss: 0.0279
# Epoch 32/80
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0183
# Epoch 00032: val_loss did not improve from 0.00698
# 3/3 [==============================] - 0s 42ms/step - loss: 0.0148 - val_loss: 0.0259
# Epoch 33/80
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0152
# Epoch 00033: val_loss did not improve from 0.00698
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0113 - val_loss: 0.0135
# Epoch 34/80
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0046
# Epoch 00034: val_loss improved from 0.00698 to 0.00569, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 301ms/step - loss: 0.0040 - val_loss: 0.0057
# Epoch 35/80
# 3/3 [==============================] - ETA: 0s - loss: 0.0024
# Epoch 00035: val_loss did not improve from 0.00569
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0024 - val_loss: 0.0058
# Epoch 36/80
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0038
# Epoch 00036: val_loss did not improve from 0.00569
# 3/3 [==============================] - 0s 48ms/step - loss: 0.0048 - val_loss: 0.0064
# Epoch 37/80
# 3/3 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 00037: val_loss improved from 0.00569 to 0.00516, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 249ms/step - loss: 0.0054 - val_loss: 0.0052
# Epoch 38/80
# 2/3 [===================>..........] - ETA: 0s - loss: 0.0033
# Epoch 00038: val_loss improved from 0.00516 to 0.00486, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 382ms/step - loss: 0.0034 - val_loss: 0.0049
# Epoch 39/80
# 1/3 [=========>....................] - ETA: 0s - loss: 9.1756e-04
# Epoch 00039: val_loss did not improve from 0.00486
# 3/3 [==============================] - 0s 51ms/step - loss: 0.0018 - val_loss: 0.0060
# Epoch 40/80
# 1/3 [=========>....................] - ETA: 0s - loss: 9.9278e-04
# Epoch 00040: val_loss did not improve from 0.00486
# 3/3 [==============================] - 0s 61ms/step - loss: 0.0019 - val_loss: 0.0067
# Epoch 41/80
# 2/3 [===================>..........] - ETA: 0s - loss: 0.0019
# Epoch 00041: val_loss did not improve from 0.00486
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0022 - val_loss: 0.0061
# Epoch 42/80
# 3/3 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 00042: val_loss improved from 0.00486 to 0.00485, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 307ms/step - loss: 0.0019 - val_loss: 0.0049
# Epoch 43/80
# 1/3 [=========>....................] - ETA: 0s - loss: 6.2984e-04
# Epoch 00043: val_loss improved from 0.00485 to 0.00383, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 289ms/step - loss: 0.0014 - val_loss: 0.0038
# Epoch 44/80
# 1/3 [=========>....................] - ETA: 0s - loss: 5.8428e-04
# Epoch 00044: val_loss improved from 0.00383 to 0.00339, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 288ms/step - loss: 0.0015 - val_loss: 0.0034
# Epoch 45/80
# 1/3 [=========>....................] - ETA: 0s - loss: 8.2255e-04
# Epoch 00045: val_loss improved from 0.00339 to 0.00324, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 261ms/step - loss: 0.0016 - val_loss: 0.0032
# Epoch 46/80
# 1/3 [=========>....................] - ETA: 0s - loss: 7.6384e-04
# Epoch 00046: val_loss did not improve from 0.00324
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0015 - val_loss: 0.0032
# Epoch 47/80
# 1/3 [=========>....................] - ETA: 0s - loss: 5.0812e-04
# Epoch 00047: val_loss did not improve from 0.00324
# 3/3 [==============================] - 0s 47ms/step - loss: 0.0012 - val_loss: 0.0034
# Epoch 48/80
# 3/3 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 00048: val_loss did not improve from 0.00324
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0011 - val_loss: 0.0034
# Epoch 49/80
# 3/3 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 00049: val_loss did not improve from 0.00324
# 3/3 [==============================] - 0s 56ms/step - loss: 0.0011 - val_loss: 0.0033
# Epoch 50/80
# 1/3 [=========>....................] - ETA: 0s - loss: 4.5183e-04
# Epoch 00050: val_loss improved from 0.00324 to 0.00304, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 321ms/step - loss: 0.0010 - val_loss: 0.0030
# Epoch 51/80
# 1/3 [=========>....................] - ETA: 0s - loss: 3.8341e-04
# Epoch 00051: val_loss improved from 0.00304 to 0.00270, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 290ms/step - loss: 9.6503e-04 - val_loss: 0.0027
# Epoch 52/80
# 1/3 [=========>....................] - ETA: 0s - loss: 3.4029e-04
# Epoch 00052: val_loss improved from 0.00270 to 0.00243, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 296ms/step - loss: 9.2519e-04 - val_loss: 0.0024
# Epoch 53/80
# 1/3 [=========>....................] - ETA: 0s - loss: 3.4194e-04
# Epoch 00053: val_loss improved from 0.00243 to 0.00230, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 342ms/step - loss: 9.0333e-04 - val_loss: 0.0023
# Epoch 54/80
# 1/3 [=========>....................] - ETA: 0s - loss: 3.3619e-04
# Epoch 00054: val_loss improved from 0.00230 to 0.00225, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 313ms/step - loss: 8.6075e-04 - val_loss: 0.0022
# Epoch 55/80
# 1/3 [=========>....................] - ETA: 0s - loss: 3.0866e-04
# Epoch 00055: val_loss improved from 0.00225 to 0.00221, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 278ms/step - loss: 7.9943e-04 - val_loss: 0.0022
# Epoch 56/80
# 1/3 [=========>....................] - ETA: 0s - loss: 2.8196e-04
# Epoch 00056: val_loss improved from 0.00221 to 0.00214, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 275ms/step - loss: 7.4331e-04 - val_loss: 0.0021
# Epoch 57/80
# 2/3 [===================>..........] - ETA: 0s - loss: 5.7288e-04
# Epoch 00057: val_loss improved from 0.00214 to 0.00203, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 332ms/step - loss: 6.9902e-04 - val_loss: 0.0020
# Epoch 58/80
# 3/3 [==============================] - ETA: 0s - loss: 6.6105e-04
# Epoch 00058: val_loss improved from 0.00203 to 0.00190, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 291ms/step - loss: 6.6105e-04 - val_loss: 0.0019
# Epoch 59/80
# 1/3 [=========>....................] - ETA: 0s - loss: 2.3403e-04
# Epoch 00059: val_loss improved from 0.00190 to 0.00176, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 278ms/step - loss: 6.2843e-04 - val_loss: 0.0018
# Epoch 60/80
# 1/3 [=========>....................] - ETA: 0s - loss: 2.2525e-04
# Epoch 00060: val_loss improved from 0.00176 to 0.00163, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 279ms/step - loss: 6.0082e-04 - val_loss: 0.0016
# Epoch 61/80
# 1/3 [=========>....................] - ETA: 0s - loss: 2.1651e-04
# Epoch 00061: val_loss improved from 0.00163 to 0.00154, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 357ms/step - loss: 5.7243e-04 - val_loss: 0.0015
# Epoch 62/80
# 1/3 [=========>....................] - ETA: 0s - loss: 2.0313e-04
# Epoch 00062: val_loss improved from 0.00154 to 0.00147, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 283ms/step - loss: 5.3967e-04 - val_loss: 0.0015
# Epoch 63/80
# 1/3 [=========>....................] - ETA: 0s - loss: 1.8850e-04
# Epoch 00063: val_loss improved from 0.00147 to 0.00141, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 284ms/step - loss: 5.0566e-04 - val_loss: 0.0014
# Epoch 64/80
# 1/3 [=========>....................] - ETA: 0s - loss: 1.7695e-04
# Epoch 00064: val_loss improved from 0.00141 to 0.00134, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 279ms/step - loss: 4.7449e-04 - val_loss: 0.0013
# Epoch 65/80
# 3/3 [==============================] - ETA: 0s - loss: 4.4688e-04
# Epoch 00065: val_loss improved from 0.00134 to 0.00126, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 324ms/step - loss: 4.4688e-04 - val_loss: 0.0013
# Epoch 66/80
# 3/3 [==============================] - ETA: 0s - loss: 4.2190e-04
# Epoch 00066: val_loss improved from 0.00126 to 0.00118, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 291ms/step - loss: 4.2190e-04 - val_loss: 0.0012
# Epoch 67/80
# 1/3 [=========>....................] - ETA: 0s - loss: 1.4908e-04
# Epoch 00067: val_loss improved from 0.00118 to 0.00110, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 306ms/step - loss: 3.9868e-04 - val_loss: 0.0011
# Epoch 68/80
# 1/3 [=========>....................] - ETA: 0s - loss: 1.4043e-04
# Epoch 00068: val_loss improved from 0.00110 to 0.00103, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 280ms/step - loss: 3.7650e-04 - val_loss: 0.0010
# Epoch 69/80
# 3/3 [==============================] - ETA: 0s - loss: 3.5477e-04
# Epoch 00069: val_loss improved from 0.00103 to 0.00097, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 364ms/step - loss: 3.5477e-04 - val_loss: 9.7339e-04
# Epoch 70/80
# 1/3 [=========>....................] - ETA: 0s - loss: 1.2508e-04
# Epoch 00070: val_loss improved from 0.00097 to 0.00092, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 278ms/step - loss: 3.3340e-04 - val_loss: 9.2151e-04
# Epoch 71/80
# 1/3 [=========>....................] - ETA: 0s - loss: 1.1735e-04
# Epoch 00071: val_loss improved from 0.00092 to 0.00087, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 313ms/step - loss: 3.1270e-04 - val_loss: 8.6942e-04
# Epoch 72/80
# 1/3 [=========>....................] - ETA: 0s - loss: 1.0980e-04
# Epoch 00072: val_loss improved from 0.00087 to 0.00082, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 329ms/step - loss: 2.9317e-04 - val_loss: 8.1677e-04
# Epoch 73/80
# 1/3 [=========>....................] - ETA: 0s - loss: 1.0289e-04
# Epoch 00073: val_loss improved from 0.00082 to 0.00077, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 293ms/step - loss: 2.7517e-04 - val_loss: 7.6509e-04
# Epoch 74/80
# 1/3 [=========>....................] - ETA: 0s - loss: 9.6774e-05
# Epoch 00074: val_loss improved from 0.00077 to 0.00072, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 298ms/step - loss: 2.5860e-04 - val_loss: 7.1575e-04
# Epoch 75/80
# 1/3 [=========>....................] - ETA: 0s - loss: 9.1119e-05
# Epoch 00075: val_loss improved from 0.00072 to 0.00067, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 272ms/step - loss: 2.4302e-04 - val_loss: 6.6892e-04
# Epoch 76/80
# 1/3 [=========>....................] - ETA: 0s - loss: 8.5554e-05
# Epoch 00076: val_loss improved from 0.00067 to 0.00063, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 298ms/step - loss: 2.2803e-04 - val_loss: 6.2696e-04
# Epoch 77/80
# 1/3 [=========>....................] - ETA: 0s - loss: 8.0047e-05
# Epoch 00077: val_loss improved from 0.00063 to 0.00059, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 300ms/step - loss: 2.1356e-04 - val_loss: 5.8853e-04
# Epoch 78/80
# 1/3 [=========>....................] - ETA: 0s - loss: 7.4855e-05
# Epoch 00078: val_loss improved from 0.00059 to 0.00055, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 294ms/step - loss: 1.9978e-04 - val_loss: 5.5200e-04
# Epoch 79/80
# 1/3 [=========>....................] - ETA: 0s - loss: 7.0055e-05
# Epoch 00079: val_loss improved from 0.00055 to 0.00052, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 291ms/step - loss: 1.8682e-04 - val_loss: 5.1705e-04
# Epoch 80/80
# 1/3 [=========>....................] - ETA: 0s - loss: 6.5610e-05
# Epoch 00080: val_loss improved from 0.00052 to 0.00048, saving model to checkpoint/
# INFO:tensorflow:Assets written to: checkpoint/assets
# 3/3 [==============================] - 1s 267ms/step - loss: 1.7477e-04 - val_loss: 4.8272e-04

# %%
# from numba import cuda

# device = cuda.get_current_device()
# device.reset()

# %%
model = create_model()
model.load_weights("checkpoint/")

# %%
def get_model_accuracy(model):
    prediction = list()
    history = [x for x in X_train]
    
#     for i in range(len(X_test)):
#         input_data = history[-1]
#         print(input_data)
#         input_data = input_data.reshape(1, input_data.shape[0], input_data.shape[1])
        
#         yhat = model.predict(input_data)
#         prediction.append(yhat)
        
#         history.append(X_test[i])
    with tf.device("/cpu:0"):
        prediction = model.predict(X_test)
#     prediction = np.array(prediction)
#     prediction = prediction.reshape(prediction.shape[0], prediction.shape[1] * prediction.shape[2])
    
    df_test = pd.DataFrame(data={"actual": y_test[:, 0], "predicted": prediction[:, 0]})
    
    # Get the root mean squared error (RMSE)
    rmse = np.sqrt(np.mean(((prediction - y_test) ** 2)))
    print(f"\nRoot Mean Square Error {rmse}")
    
    return r2_score(y_true=y_test, y_pred=prediction), df_test

# %%
score, df_ = get_model_accuracy(model)
print(f"accuracy = {round(score, 2)}\n")
df_
# Out:
# Root Mean Square Error 0.005486698877196469
# accuracy = 1.0
#    actual  predicted
# 0    0.00   0.006470
# 1   38.72  38.720692
# 2    0.00   0.000417
# 3   50.20  50.191174

# %%
df_.plot()
plt.show()

# %%
# model.predict(X_train[-2].reshape(1, X_test[-1].shape[0], X_test[-1].shape[1]))
# model.predict(X_train[-2].reshape(1, X_train[-2].shape[0]))
