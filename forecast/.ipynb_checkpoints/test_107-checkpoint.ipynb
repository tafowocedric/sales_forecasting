# %%
import pandas as pd
import numpy as np

import tensorflow as tf
import tensorflow.compat.v1 as tfv1

import IPython
from IPython.display import display

import matplotlib as mpl
import matplotlib.pyplot as plt

from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from collections import deque

import os
import datetime
import seaborn as sns

import random
import time

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False

# %%
df = pd.read_csv("universe_dataset.csv", index_col="txn_date")
df.head()
# Out:
#             gross_amount  gross_cost  margin  tax_amount
# txn_date
# 2020-05-19      0.830373         0.0   391.5        10.5
# 2020-06-19      0.817810       125.0   240.0        22.0
# 2020-06-26      0.635229        81.0    75.0         0.0
# 2020-07-16      0.000000         0.0    75.0         0.0
# 2020-07-17      0.946910       125.0   661.6        44.4

# %%
date = pd.to_datetime(df.index, format='%Y.%m.%d')

# %%
df.plot(subplots=True)
plt.show()

# %%
df.describe().transpose()
# Out:
#               count        mean         std   min        25%         50%  \
# gross_amount   18.0    0.651265    0.340558   0.0   0.344696    0.810791
# gross_cost     18.0   63.777778  104.738641   0.0   0.000000    0.000000
# margin         18.0  336.260000  273.593258  75.0  80.000000  289.000000
# tax_amount     18.0   14.906667   19.958931   0.0   0.000000    3.000000
#
#                      75%    max
# gross_amount    0.895875    1.0
# gross_cost    125.000000  407.0
# margin        528.700000  975.0
# tax_amount     34.540000   50.2

# %%
np.random.seed(314)
tf.random.set_seed(314)
tfv1.random.set_random_seed(314)
random.seed(314)

# %% [markdown]
# Preparing the Dataset
# =====================
# As a first step, we need to write a function that downloads the dataset from the Internet and preprocess it:

# %%
def shuffle_in_unison(a, b):
    # shuffle two arrays in the same way
    state = np.random.get_state()
    np.random.shuffle(a)
    np.random.set_state(state)
    np.random.shuffle(b)

def load_data(df, n_steps=5, scale=True, shuffle=True, lookup_step=1, split_by_date=True, test_size=0.2, feature_columns=list(df.columns)):
    if not isinstance(df, pd.DataFrame):
        raise TypeError("Data can only be a pd.DataFrame instance")
        
           
    # this will contain all the elements we want to return from this function
    result = {}
    
    result["df"] = df.copy()
    
    # make sure that the passed cols exist in the dataframe
    for col in feature_columns:
        assert col in df.columns, f"'{col}' does not exist in the dataframe."
        
    # add date to dataframe if not exist
    if "date" not in df.columns:
        df["date"] = df.index
        
    if scale:
        column_scaler = {}
        
        # Scale the data (price) from 0 - 1
        for column in feature_columns:
            if column == "date":
                pass
            
            scaler = preprocessing.MinMaxScaler()
            df[column] = scaler.fit_transform(np.expand_dims(df[column].values, axis=1))
            column_scaler[column] = scaler
            
        # add the MinMaxScaler instances to the result returned
        result["column_scaler"] = column_scaler
        
    # add the target column (label) by shifting by `look_back`
    df["future"] = df["gross_amount"].shift(-lookup_step)
    
    # last `lookup_step` columns contains NaN in future column
    # get them before droping NaNs
    last_sequence = np.array(df[feature_columns].tail(lookup_step), dtype=np.float32)
        
    # drop NaNs
    df.dropna(inplace=True)
    
    sequence_data = []
    sequences = deque(maxlen=n_steps)
    

    for entry, target in zip(df[feature_columns + ["date"]].values, df["future"].values):
        sequences.append(entry)
        
        if len(sequences) == n_steps:
            sequence_data.append([np.array(sequences), target])
            
    # get the last sequence by appending the last `n_step` sequence with `lookup_step` sequence
    # for instance, if n_steps=50 and lookup_step=10, last_sequence should be of 60 (that is 50+10) length
    # this last_sequence will be used to predict gross_amount revenue that are not available in the dataset
    
    last_sequence = list([s[: len(feature_columns)] for s in sequences]) + list(last_sequence)
    last_sequence = np.array(last_sequence).astype(np.float32)
    
    # add to result
    result["last_sequence"] = last_sequence
    
    # construct the X and y
    X, y = [], []
    
    for seq, target in sequence_data:
        X.append(seq)
        y.append(target)
        
    # Convert to numpy arrays
    X = np.array(X)
    y = np.array(y)   
    
    if split_by_date:
        # split the dataset into training & testing set by date (not randomly splitting)
        train_samples = int((1 - test_size) * len(X))
        
        result["X_train"] = X[:train_samples]
        result["y_train"] = y[:train_samples]
        result["X_test"] = X[train_samples:]
        result["y_test"] = y[train_samples:]
        
        if shuffle:
            # shuffle the datasets for training (if shuffle parameter is set)
            shuffle_in_unison(result["X_train"], result["y_train"])
            shuffle_in_unison(result["X_test"], result["y_test"])
            
    else:    
        # split the dataset randomly
        result["X_train"], result["X_test"], result["y_train"], result["y_test"] = train_test_split(X, y, test_size=test_size, shuffle=shuffle)
    
    # get the list of test set dates
    dates = result["X_test"][:, -1, -1]
    
    # retrive test features from the original dataframe
    result["test_df"] = result["df"].loc[dates]
    
    # remove duplicates dates in the testing dataframe
    result["test_df"] = result["test_df"][~result["test_df"].index.duplicated(keep='first')]
      
    # remove dates from the training/testing sets & convert to float32
    result["X_train"] = result["X_train"][:, :, :len(feature_columns)].astype(np.float32)
    result["X_test"] = result["X_test"][:, :, :len(feature_columns)].astype(np.float32)
    
    return result

# %% [markdown]
# Model Creation
# ==============
# Now that we have a proper function to load and prepare the dataset, we need another core function to build our model:

# %%
from tensorflow.keras.layers import Dense, Bidirectional, Dropout, LSTM

def create_model(sequence_length, n_features, units=256, cell=LSTM, n_layers=2, dropout=0.3, loss="mean_absolute_error", optimizer="rmsprop", bidirectional=False):
    model = tfv1.keras.Sequential()
    
    for i in range(n_layers):
        if i == 0:
            # first layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True), batch_input_shape=(None, sequence_length, n_features)))
                
            else:
                model.add(cell(units, return_sequences=True, batch_input_shape=(None, sequence_length, n_features)))
                
        elif i == n_layers - 1:
            # last layer
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=False)))
                
            else:
                model.add(cell(units, return_sequences=False))
                
        else:
            # hidden layers
            if bidirectional:
                model.add(Bidirectional(cell(units, return_sequences=True)))
                
            else:
                model.add(cell(units, return_sequences=True))
                
        # add dropout after each layer
        model.add(Dropout(dropout))
        
    model.add(Dense(1, activation="linear"))
    model.compile(loss=loss, metrics=["mean_absolute_error"], optimizer=optimizer)
    
    return model

# %% [markdown]
# Training the Model
# ==================
# Now that we have all the core functions ready, let's train our model, but before we do that, let's initialize all our parameters

# %%
# Window size or the sequence length
N_STEPS = 6

# Lookup step, 1 is the next day
LOOKUP_STEP = 1

# whether to scale feature columns & output price as well
SCALE = False
scale_str = f"sc-{int(SCALE)}"

# whether to shuffle the dataset
SHUFFLE = True
shuffle_str = f"sh-{int(SHUFFLE)}"

# whether to split the training/testing set by date
SPLIT_BY_DATE = True
split_by_date_str = f"sbd-{int(SPLIT_BY_DATE)}"

# test ratio size, 0.2 is 20%
TEST_SIZE = 0.3

# features to use
FEATURE_COLUMNS = list(df.columns)

# date now
date_now = time.strftime("%Y-%m-%d")

### model parameters
N_LAYERS = 2

# LSTM cell
CELL = tfv1.keras.layers.GRU

# 256 LSTM neurons
UNITS = 5 #256

# 40% dropout
DROPOUT = 0.2

# whether to use bidirectional RNNs
BIDIRECTIONAL = False

### TRAINING PARAMETERS
# mean absolute error loss
# LOSS = "mae"
# huber loss
LOSS = "huber_loss"

OPTIMIZER = "adam"
BATCH_SIZE = 5
EPOCHS = 50

ticker = "UNIVERS"
# model name to save, making it as unique as possible based on parameters
model_name = f"{date_now}_{ticker}-{shuffle_str}-{scale_str}-{split_by_date_str}-{LOSS}-{OPTIMIZER}-{CELL.__name__}-seq-{N_STEPS}-step-{LOOKUP_STEP}-layers-{N_LAYERS}-units-{UNITS}"

if BIDIRECTIONAL:
    model_name += "-b"
    
model_name
# Out:
# '2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5'

# %%
# create these folders if they does not exist
if not os.path.isdir("results"):
    os.mkdir("results")
if not os.path.isdir("logs"):
    os.mkdir("logs")

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard

# load the data
data = load_data(df, N_STEPS, scale=SCALE, split_by_date=SPLIT_BY_DATE, shuffle=SHUFFLE, lookup_step=LOOKUP_STEP, test_size=TEST_SIZE, feature_columns=FEATURE_COLUMNS)

# construct the model
model = create_model(N_STEPS, len(FEATURE_COLUMNS), loss=LOSS, units=UNITS, cell=CELL, n_layers=N_LAYERS, dropout=DROPOUT, optimizer=OPTIMIZER, bidirectional=BIDIRECTIONAL)
tf.keras.utils.plot_model(model, to_file='model.png', show_shapes=True, expand_nested=True)

# some tensorflow callbacks
checkpointer = ModelCheckpoint(os.path.join("results", model_name + ".h5"), save_weights_only=True, save_best_only=True, verbose=1)
tensorboard = TensorBoard(log_dir=os.path.join("logs", model_name))

# %%
data["X_train"].shape
# Out:
# (8, 6, 4)

# %%
# train the model and save the weights whenever we see 
# a new optimal model using ModelCheckpoint
history = model.fit(data["X_train"], data["y_train"], batch_size=BATCH_SIZE, epochs=EPOCHS, validation_data=(data["X_test"], data["y_test"]),
                    callbacks=[checkpointer, tensorboard], verbose=1)
# Out:
# Epoch 1/50
# 2/2 [==============================] - ETA: 0s - loss: 0.2556 - mean_absolute_error: 0.6450
# Epoch 00001: val_loss improved from inf to 0.41989, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 2s 899ms/step - loss: 0.2556 - mean_absolute_error: 0.6450 - val_loss: 0.4199 - val_mean_absolute_error: 0.9149
# Epoch 2/50
# 2/2 [==============================] - ETA: 0s - loss: 0.2140 - mean_absolute_error: 0.5652
# Epoch 00002: val_loss improved from 0.41989 to 0.40315, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 140ms/step - loss: 0.2140 - mean_absolute_error: 0.5652 - val_loss: 0.4032 - val_mean_absolute_error: 0.8965
# Epoch 3/50
# 2/2 [==============================] - ETA: 0s - loss: 0.2373 - mean_absolute_error: 0.5961
# Epoch 00003: val_loss improved from 0.40315 to 0.38673, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 132ms/step - loss: 0.2373 - mean_absolute_error: 0.5961 - val_loss: 0.3867 - val_mean_absolute_error: 0.8782
# Epoch 4/50
# 2/2 [==============================] - ETA: 0s - loss: 0.2442 - mean_absolute_error: 0.6036
# Epoch 00004: val_loss improved from 0.38673 to 0.37072, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 139ms/step - loss: 0.2442 - mean_absolute_error: 0.6036 - val_loss: 0.3707 - val_mean_absolute_error: 0.8598
# Epoch 5/50
# 2/2 [==============================] - ETA: 0s - loss: 0.1870 - mean_absolute_error: 0.5085
# Epoch 00005: val_loss improved from 0.37072 to 0.35532, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 75ms/step - loss: 0.1870 - mean_absolute_error: 0.5085 - val_loss: 0.3553 - val_mean_absolute_error: 0.8418
# Epoch 6/50
# 2/2 [==============================] - ETA: 0s - loss: 0.1771 - mean_absolute_error: 0.4770
# Epoch 00006: val_loss improved from 0.35532 to 0.34104, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1771 - mean_absolute_error: 0.4770 - val_loss: 0.3410 - val_mean_absolute_error: 0.8248
# Epoch 7/50
# 2/2 [==============================] - ETA: 0s - loss: 0.2302 - mean_absolute_error: 0.5986
# Epoch 00007: val_loss improved from 0.34104 to 0.32698, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 76ms/step - loss: 0.2302 - mean_absolute_error: 0.5986 - val_loss: 0.3270 - val_mean_absolute_error: 0.8077
# Epoch 8/50
# 2/2 [==============================] - ETA: 0s - loss: 0.1904 - mean_absolute_error: 0.5230
# Epoch 00008: val_loss improved from 0.32698 to 0.31327, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1904 - mean_absolute_error: 0.5230 - val_loss: 0.3133 - val_mean_absolute_error: 0.7906
# Epoch 9/50
# 2/2 [==============================] - ETA: 0s - loss: 0.1399 - mean_absolute_error: 0.4347
# Epoch 00009: val_loss improved from 0.31327 to 0.29987, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 122ms/step - loss: 0.1399 - mean_absolute_error: 0.4347 - val_loss: 0.2999 - val_mean_absolute_error: 0.7735
# Epoch 10/50
# 2/2 [==============================] - ETA: 0s - loss: 0.1748 - mean_absolute_error: 0.4869
# Epoch 00010: val_loss improved from 0.29987 to 0.28736, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 78ms/step - loss: 0.1748 - mean_absolute_error: 0.4869 - val_loss: 0.2874 - val_mean_absolute_error: 0.7573
# Epoch 11/50
# 2/2 [==============================] - ETA: 0s - loss: 0.1572 - mean_absolute_error: 0.4737
# Epoch 00011: val_loss improved from 0.28736 to 0.27540, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 146ms/step - loss: 0.1572 - mean_absolute_error: 0.4737 - val_loss: 0.2754 - val_mean_absolute_error: 0.7414
# Epoch 12/50
# 2/2 [==============================] - ETA: 0s - loss: 0.1722 - mean_absolute_error: 0.5304
# Epoch 00012: val_loss improved from 0.27540 to 0.26373, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 141ms/step - loss: 0.1722 - mean_absolute_error: 0.5304 - val_loss: 0.2637 - val_mean_absolute_error: 0.7255
# Epoch 13/50
# 2/2 [==============================] - ETA: 0s - loss: 0.1499 - mean_absolute_error: 0.4531
# Epoch 00013: val_loss improved from 0.26373 to 0.25180, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 131ms/step - loss: 0.1499 - mean_absolute_error: 0.4531 - val_loss: 0.2518 - val_mean_absolute_error: 0.7089
# Epoch 14/50
# 2/2 [==============================] - ETA: 0s - loss: 0.1027 - mean_absolute_error: 0.3841
# Epoch 00014: val_loss improved from 0.25180 to 0.23995, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 135ms/step - loss: 0.1027 - mean_absolute_error: 0.3841 - val_loss: 0.2400 - val_mean_absolute_error: 0.6921
# Epoch 15/50
# 2/2 [==============================] - ETA: 0s - loss: 0.1554 - mean_absolute_error: 0.4587
# Epoch 00015: val_loss improved from 0.23995 to 0.22890, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 121ms/step - loss: 0.1554 - mean_absolute_error: 0.4587 - val_loss: 0.2289 - val_mean_absolute_error: 0.6760
# Epoch 16/50
# 2/2 [==============================] - ETA: 0s - loss: 0.1468 - mean_absolute_error: 0.4396
# Epoch 00016: val_loss improved from 0.22890 to 0.21809, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 159ms/step - loss: 0.1468 - mean_absolute_error: 0.4396 - val_loss: 0.2181 - val_mean_absolute_error: 0.6598
# Epoch 17/50
# 2/2 [==============================] - ETA: 0s - loss: 0.1122 - mean_absolute_error: 0.3913
# Epoch 00017: val_loss improved from 0.21809 to 0.20744, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 152ms/step - loss: 0.1122 - mean_absolute_error: 0.3913 - val_loss: 0.2074 - val_mean_absolute_error: 0.6435
# Epoch 18/50
# 2/2 [==============================] - ETA: 0s - loss: 0.1681 - mean_absolute_error: 0.4778
# Epoch 00018: val_loss improved from 0.20744 to 0.19799, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 90ms/step - loss: 0.1681 - mean_absolute_error: 0.4778 - val_loss: 0.1980 - val_mean_absolute_error: 0.6287
# Epoch 19/50
# 2/2 [==============================] - ETA: 0s - loss: 0.1145 - mean_absolute_error: 0.4132
# Epoch 00019: val_loss improved from 0.19799 to 0.18919, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 113ms/step - loss: 0.1145 - mean_absolute_error: 0.4132 - val_loss: 0.1892 - val_mean_absolute_error: 0.6146
# Epoch 20/50
# 2/2 [==============================] - ETA: 0s - loss: 0.0823 - mean_absolute_error: 0.3456
# Epoch 00020: val_loss improved from 0.18919 to 0.18088, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0823 - mean_absolute_error: 0.3456 - val_loss: 0.1809 - val_mean_absolute_error: 0.6010
# Epoch 21/50
# 2/2 [==============================] - ETA: 0s - loss: 0.0986 - mean_absolute_error: 0.3891
# Epoch 00021: val_loss improved from 0.18088 to 0.17342, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 203ms/step - loss: 0.0986 - mean_absolute_error: 0.3891 - val_loss: 0.1734 - val_mean_absolute_error: 0.5884
# Epoch 22/50
# 2/2 [==============================] - ETA: 0s - loss: 0.1302 - mean_absolute_error: 0.4346
# Epoch 00022: val_loss improved from 0.17342 to 0.16644, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 115ms/step - loss: 0.1302 - mean_absolute_error: 0.4346 - val_loss: 0.1664 - val_mean_absolute_error: 0.5765
# Epoch 23/50
# 2/2 [==============================] - ETA: 0s - loss: 0.1376 - mean_absolute_error: 0.4506
# Epoch 00023: val_loss improved from 0.16644 to 0.16011, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1376 - mean_absolute_error: 0.4506 - val_loss: 0.1601 - val_mean_absolute_error: 0.5654
# Epoch 24/50
# 2/2 [==============================] - ETA: 0s - loss: 0.0720 - mean_absolute_error: 0.3127
# Epoch 00024: val_loss improved from 0.16011 to 0.15349, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0720 - mean_absolute_error: 0.3127 - val_loss: 0.1535 - val_mean_absolute_error: 0.5536
# Epoch 25/50
# 2/2 [==============================] - ETA: 0s - loss: 0.0941 - mean_absolute_error: 0.3791
# Epoch 00025: val_loss improved from 0.15349 to 0.14652, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 165ms/step - loss: 0.0941 - mean_absolute_error: 0.3791 - val_loss: 0.1465 - val_mean_absolute_error: 0.5409
# Epoch 26/50
# 2/2 [==============================] - ETA: 0s - loss: 0.0908 - mean_absolute_error: 0.3746
# Epoch 00026: val_loss improved from 0.14652 to 0.14073, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 202ms/step - loss: 0.0908 - mean_absolute_error: 0.3746 - val_loss: 0.1407 - val_mean_absolute_error: 0.5300
# Epoch 27/50
# 2/2 [==============================] - ETA: 0s - loss: 0.0802 - mean_absolute_error: 0.3640
# Epoch 00027: val_loss improved from 0.14073 to 0.13574, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 147ms/step - loss: 0.0802 - mean_absolute_error: 0.3640 - val_loss: 0.1357 - val_mean_absolute_error: 0.5205
# Epoch 28/50
# 2/2 [==============================] - ETA: 0s - loss: 0.0870 - mean_absolute_error: 0.3918
# Epoch 00028: val_loss improved from 0.13574 to 0.13094, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 169ms/step - loss: 0.0870 - mean_absolute_error: 0.3918 - val_loss: 0.1309 - val_mean_absolute_error: 0.5112
# Epoch 29/50
# 2/2 [==============================] - ETA: 0s - loss: 0.1229 - mean_absolute_error: 0.4657
# Epoch 00029: val_loss improved from 0.13094 to 0.12639, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 108ms/step - loss: 0.1229 - mean_absolute_error: 0.4657 - val_loss: 0.1264 - val_mean_absolute_error: 0.5023
# Epoch 30/50
# 2/2 [==============================] - ETA: 0s - loss: 0.0766 - mean_absolute_error: 0.3518
# Epoch 00030: val_loss improved from 0.12639 to 0.12201, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 161ms/step - loss: 0.0766 - mean_absolute_error: 0.3518 - val_loss: 0.1220 - val_mean_absolute_error: 0.4935
# Epoch 31/50
# 2/2 [==============================] - ETA: 0s - loss: 0.0926 - mean_absolute_error: 0.3833
# Epoch 00031: val_loss improved from 0.12201 to 0.11760, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 173ms/step - loss: 0.0926 - mean_absolute_error: 0.3833 - val_loss: 0.1176 - val_mean_absolute_error: 0.4845
# Epoch 32/50
# 2/2 [==============================] - ETA: 0s - loss: 0.0811 - mean_absolute_error: 0.3553
# Epoch 00032: val_loss improved from 0.11760 to 0.11333, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 118ms/step - loss: 0.0811 - mean_absolute_error: 0.3553 - val_loss: 0.1133 - val_mean_absolute_error: 0.4756
# Epoch 33/50
# 2/2 [==============================] - ETA: 0s - loss: 0.0737 - mean_absolute_error: 0.3512
# Epoch 00033: val_loss improved from 0.11333 to 0.10906, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 127ms/step - loss: 0.0737 - mean_absolute_error: 0.3512 - val_loss: 0.1091 - val_mean_absolute_error: 0.4665
# Epoch 34/50
# 2/2 [==============================] - ETA: 0s - loss: 0.0760 - mean_absolute_error: 0.3418
# Epoch 00034: val_loss improved from 0.10906 to 0.10531, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0760 - mean_absolute_error: 0.3418 - val_loss: 0.1053 - val_mean_absolute_error: 0.4584
# Epoch 35/50
# 2/2 [==============================] - ETA: 0s - loss: 0.0843 - mean_absolute_error: 0.3690
# Epoch 00035: val_loss improved from 0.10531 to 0.10186, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 86ms/step - loss: 0.0843 - mean_absolute_error: 0.3690 - val_loss: 0.1019 - val_mean_absolute_error: 0.4508
# Epoch 36/50
# 2/2 [==============================] - ETA: 0s - loss: 0.0634 - mean_absolute_error: 0.3226
# Epoch 00036: val_loss improved from 0.10186 to 0.09796, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 151ms/step - loss: 0.0634 - mean_absolute_error: 0.3226 - val_loss: 0.0980 - val_mean_absolute_error: 0.4421
# Epoch 37/50
# 2/2 [==============================] - ETA: 0s - loss: 0.0437 - mean_absolute_error: 0.2715
# Epoch 00037: val_loss improved from 0.09796 to 0.09402, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 118ms/step - loss: 0.0437 - mean_absolute_error: 0.2715 - val_loss: 0.0940 - val_mean_absolute_error: 0.4331
# Epoch 38/50
# 2/2 [==============================] - ETA: 0s - loss: 0.1164 - mean_absolute_error: 0.4241
# Epoch 00038: val_loss improved from 0.09402 to 0.09068, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 120ms/step - loss: 0.1164 - mean_absolute_error: 0.4241 - val_loss: 0.0907 - val_mean_absolute_error: 0.4253
# Epoch 39/50
# 2/2 [==============================] - ETA: 0s - loss: 0.0584 - mean_absolute_error: 0.3049
# Epoch 00039: val_loss improved from 0.09068 to 0.08817, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 133ms/step - loss: 0.0584 - mean_absolute_error: 0.3049 - val_loss: 0.0882 - val_mean_absolute_error: 0.4194
# Epoch 40/50
# 2/2 [==============================] - ETA: 0s - loss: 0.0716 - mean_absolute_error: 0.3575
# Epoch 00040: val_loss improved from 0.08817 to 0.08582, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 121ms/step - loss: 0.0716 - mean_absolute_error: 0.3575 - val_loss: 0.0858 - val_mean_absolute_error: 0.4137
# Epoch 41/50
# 2/2 [==============================] - ETA: 0s - loss: 0.0493 - mean_absolute_error: 0.2774
# Epoch 00041: val_loss improved from 0.08582 to 0.08385, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 176ms/step - loss: 0.0493 - mean_absolute_error: 0.2774 - val_loss: 0.0838 - val_mean_absolute_error: 0.4089
# Epoch 42/50
# 2/2 [==============================] - ETA: 0s - loss: 0.0730 - mean_absolute_error: 0.3132
# Epoch 00042: val_loss improved from 0.08385 to 0.08249, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 146ms/step - loss: 0.0730 - mean_absolute_error: 0.3132 - val_loss: 0.0825 - val_mean_absolute_error: 0.4056
# Epoch 43/50
# 2/2 [==============================] - ETA: 0s - loss: 0.1106 - mean_absolute_error: 0.4130
# Epoch 00043: val_loss improved from 0.08249 to 0.08194, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 132ms/step - loss: 0.1106 - mean_absolute_error: 0.4130 - val_loss: 0.0819 - val_mean_absolute_error: 0.4042
# Epoch 44/50
# 2/2 [==============================] - ETA: 0s - loss: 0.0575 - mean_absolute_error: 0.2974
# Epoch 00044: val_loss improved from 0.08194 to 0.08090, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 96ms/step - loss: 0.0575 - mean_absolute_error: 0.2974 - val_loss: 0.0809 - val_mean_absolute_error: 0.4016
# Epoch 45/50
# 2/2 [==============================] - ETA: 0s - loss: 0.0805 - mean_absolute_error: 0.3523
# Epoch 00045: val_loss improved from 0.08090 to 0.07990, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 127ms/step - loss: 0.0805 - mean_absolute_error: 0.3523 - val_loss: 0.0799 - val_mean_absolute_error: 0.3991
# Epoch 46/50
# 1/2 [==============>...............] - ETA: 0s - loss: 0.1714 - mean_absolute_error: 0.5487
# Epoch 00046: val_loss improved from 0.07990 to 0.07850, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 51ms/step - loss: 0.1296 - mean_absolute_error: 0.4554 - val_loss: 0.0785 - val_mean_absolute_error: 0.3956
# Epoch 47/50
# 2/2 [==============================] - ETA: 0s - loss: 0.0645 - mean_absolute_error: 0.3276
# Epoch 00047: val_loss improved from 0.07850 to 0.07713, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 121ms/step - loss: 0.0645 - mean_absolute_error: 0.3276 - val_loss: 0.0771 - val_mean_absolute_error: 0.3921
# Epoch 48/50
# 2/2 [==============================] - ETA: 0s - loss: 0.0604 - mean_absolute_error: 0.3051
# Epoch 00048: val_loss improved from 0.07713 to 0.07638, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 167ms/step - loss: 0.0604 - mean_absolute_error: 0.3051 - val_loss: 0.0764 - val_mean_absolute_error: 0.3902
# Epoch 49/50
# 2/2 [==============================] - ETA: 0s - loss: 0.0585 - mean_absolute_error: 0.3326
# Epoch 00049: val_loss improved from 0.07638 to 0.07585, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0585 - mean_absolute_error: 0.3326 - val_loss: 0.0759 - val_mean_absolute_error: 0.3888
# Epoch 50/50
# 2/2 [==============================] - ETA: 0s - loss: 0.0824 - mean_absolute_error: 0.3719
# Epoch 00050: val_loss improved from 0.07585 to 0.07497, saving model to results/2021-01-19_UNIVERS-sh-1-sc-1-sbd-1-huber_loss-adam-GRU-seq-6-step-1-layers-2-units-5.h5
# 2/2 [==============================] - 0s 226ms/step - loss: 0.0824 - mean_absolute_error: 0.3719 - val_loss: 0.0750 - val_mean_absolute_error: 0.3865

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs
# Out:
# Reusing TensorBoard on port 6006 (pid 11524), started 0:40:59 ago. (Use '!kill 11524' to kill it.)
#       <iframe id="tensorboard-frame-74cfe1f6324951e4" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-74cfe1f6324951e4");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# Testing the Model
# =================
# Now that we've trained our model, let's evaluate it and see how it's doing on the testing set, the below function takes a pandas Dataframe and plots the true and predicted prices in the same plot using matplotlib, we'll use it later:

# %%
def get_final_df(model, data):
    X_test = data["X_test"]
    y_test = data["y_test"]
    
    # perform prediction and get prices
    y_pred = model.predict(X_test)
    
    print(y_pred)
    print(y_test)
    if SCALE:
        y_test = np.squeeze(data["column_scaler"]["gross_amount"].inverse_transform(np.expand_dims(y_test, axis=0)))
        y_pred = np.squeeze(data["column_scaler"]["gross_amount"].inverse_transform(y_pred))
    
    print(y_pred)
    print(y_test)
        
    test_df = data["test_df"]
    
    # add predicted future prices to the dataframe
    test_df[f"gross_amount_{LOOKUP_STEP}"] = y_pred
    # add true future prices to the dataframe
    test_df[f"true_gross_amount_{LOOKUP_STEP}"] = y_test
    
    # sort the dataframe by date
    test_df.sort_index(inplace=True)
    
    return test_df

def plot_graph(test_df):
    """
    This function plots true gross_amount along with predicted gross_amount
    with blue and red colors respectively
    """
    plt.plot(test_df[f'true_gross_amount_{LOOKUP_STEP}'], c='b')
    plt.plot(test_df[f'gross_amount_{LOOKUP_STEP}'], c='r')
    plt.xlabel("Days")
    plt.ylabel("Amount")
    plt.legend(["Actual Amount", "Predicted Amount"])
    plt.show()
    
    
def predict(model, data):
    # retrieve the last sequence from data
    last_sequence = data["last_sequence"][-N_STEPS:]
    
    # expand dimension
    last_sequence = np.expand_dims(last_sequence, axis=0)
    
    # get the prediction (scaled from 0 to 1)
    prediction = model.predict(last_sequence)
    
    # get the price (by inverting the scaling)
    if SCALE:
        predicted_price = data["column_scaler"]["gross_amount"].inverse_transform(prediction)[0][0]
    else:
        predicted_price = prediction[0][0]
        
    return predicted_price
    
    
# load optimal model weights from results folder
model_path = os.path.join("results", model_name) + ".h5"
model.load_weights(model_path)

# evaluate the model
loss, mae = model.evaluate(data["X_test"], data["y_test"], verbose=0)
# calculate the mean absolute error (inverse scaling)
if SCALE:
    mean_absolute_error = data["column_scaler"]["gross_amount"].inverse_transform([[mae]])[0][0]
    
else:
    mean_absolute_error = mae
    
    
# get the final dataframe for the testing set
final_df = get_final_df(model, data)

# predict the future price
future_gross_amount = predict(model, data)
# Out:
# [[0.531615  ]
#  [0.60472596]
#  [0.53474873]
#  [0.4846196 ]]
# [0.88381645 1.         0.91817201 0.89989514]
# [0.531615   0.60472596 0.53474873 0.4846196 ]
# [0.88381645 1.         0.91817201 0.89989514]

# %%
display(future_gross_amount)
final_df
# Out:
# 0.733685
#             gross_amount  gross_cost  margin  tax_amount  gross_amount_1  \
# txn_date
# 2020-08-30      0.603939         0.0  140.00        0.00        0.484620
# 2020-08-31      0.899895         0.0  588.28       38.72        0.531615
# 2020-09-01      0.883816         0.0  534.00        0.00        0.534749
# 2020-09-02      0.918172       145.0  512.80       50.20        0.604726
#
#             true_gross_amount_1
# txn_date
# 2020-08-30             0.899895
# 2020-08-31             0.883816
# 2020-09-01             0.918172
# 2020-09-02             1.000000

# %%
# printing metrics
print(f"Future price after {LOOKUP_STEP} days is {future_gross_amount:.2f}$")

# plot true/pred prices graph
plot_graph(final_df)
# Out:
# Future price after 1 days is 0.73$
